# %%
import tweepy #https://github.com/tweepy/tweepy
import csv
import emoji
from emoji import UNICODE_EMOJI

#Twitter API credentials
consumer_key = "bfDI2oEarB0zjUZSAapZb97IP"
consumer_secret = "zRhB4IlyLFubAYAU0hwBPRnZzuRuL38EPJzfd0sRLHbrxtJRQd"
access_key = "1114621401204502528-g9KugfQTMaTN30n6Mt4U9KzIY3P5wq"
access_secret = "kCtCxgJVVEhxrVlQHNWVD6dGsIEZGsRByOSQqHLTHzak8"

map = {sum:0}
mapsum = {sum:0}

def extract_emojis(str, map):
    for c in str:
        if c in UNICODE_EMOJI:
            if c in map:
                map[c]+=1
                map[sum]+=1
            else:
                map[c] = 1
                map[sum]+=1
    return ''.join(c for c in str if c in UNICODE_EMOJI)

def get_all_tweets(screen_name):

    #Twitter only allows access to a users most recent 3240 tweets with this method

    #authorize twitter, initialize tweepy

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

    auth.set_access_token(access_key, access_secret)

    api = tweepy.API(auth)

    #initialize a list to hold all the tweepy Tweets

    alltweets = []	
    
    #make initial request for most recent tweets (200 is the maximum allowed count)

    new_tweets = api.user_timeline(screen_name = screen_name,count=200)

    #save most recent tweets

    alltweets.extend(new_tweets)

    #save the id of the oldest tweet less one

    oldest = alltweets[-1].id - 1
    
    #keep grabbing tweets until there are no tweets left to grab

    while len(new_tweets) > 0:

        print ("getting tweets before %s" % (oldest))

        #all subsiquent requests use the max_id param to prevent duplicates

        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        
        #save most recent tweets

        alltweets.extend(new_tweets)

        #update the id of the oldest tweet less one

        oldest = alltweets[-1].id - 1

        print ("...%s tweets downloaded so far" % (len(alltweets)))

    #transform the tweepy tweets into a 2D array that will populate the csv	

    outtweets = [[tweet.id_str, tweet.created_at, tweet.text, extract_emojis(tweet.text, map)] for tweet in alltweets]
    
    output = {}
    for c in map:
        print(c,map[c])
        output[c] = map[c]
        
    with open('%s_tweets111.csv' % screen_name, 'w', encoding='utf-8') as d:   
        writer = csv.writer(d)
        writer.writerow(["emoji","count"])
        for k, v in output.items():
            writer.writerow([k, str(v)])
        
    pass

    #write the csv
    with open('%s_tweets.csv' % screen_name, 'w', encoding='utf-8') as f:

        writer = csv.writer(f)

        writer.writerow(["id","created_at","text", "emojis"])

        writer.writerow(outtweets[0])
    
    pass

if __name__ == '__main__':
    #pass in the username of the account you want to download
    
    user_names = ['sudaofficial']
    
    get_all_tweets("sudaofficial")
# Out:
# getting tweets before 1071031726548299775
# ...400 tweets downloaded so far
# getting tweets before 976311664352964607
# ...590 tweets downloaded so far
# getting tweets before 908256885425397759
# ...790 tweets downloaded so far
# getting tweets before 834011120532758527
# ...990 tweets downloaded so far
# getting tweets before 717277692630933503
# ...1106 tweets downloaded so far
# getting tweets before 624362053155729407
# ...1106 tweets downloaded so far
# 🤜 1
# 🌟 2
# 🎥 4
# 💘 1
# 📽 1
# 😊 3
# 🔻 1
# 🤳 4
# 🌋 1
# 🤗 1
# 🚀 1
# 🎤 3
# 👏 11
# 📹 1
# 😂 4
# ❗ 30
# 👴 1
# 🎃 1
# 💕 8
# 👩 4
# 😇 1
# 📗 1
# 😄 6
# 🤫 2
# 🍓 1
# <built-in function sum> 879
# 💉 1
# 😆 14
# ⚠ 1
# 🙇 13
# 🤔 1
# 🎓 35
# 🎼 2
# ☺ 4
# ✊ 1
# 🕊 1
# ⁉ 19
# 💊 1
# 🦌 2
# ♀ 4
# ⌛ 5
# 🍉 1
# 🗣 2
# 🚓 1
# 😭 9
# ⭕ 1
# ⚫ 2
# 👍 5
# 🍻 1
# 🕺 1
# 🎵 4
# 🌃 1
# 🧐 1
# 🍊 4
# 👇 6
# 🤵 2
# 😁 7
# 👨 23
# ✖ 2
# 🤛 1
# 😢 1
# 🐾 1
# 🖍 1
# 👉 10
# 🎙 1
# 🌸 6
# 🎄 3
# ✨ 107
# ✌ 5
# 😵 1
# 🎅 2
# 🤣 9
# 👑 3
# 🔥 14
# ✔ 4
# ⤵ 1
# 💐 1
# 😏 4
# 😉 1
# ❄ 1
# 😘 1
# 🍀 2
# 🎉 35
# 😀 1
# 😍 14
# 🃏 1
# 😱 2
# 👔 1
# 🏫 47
# 👓 1
# ❓ 7
# 🏃 1
# 💌 1
# ‼ 87
# 🌻 2
# 🎊 12
# 💞 1
# 🥊 6
# 🤶 1
# 🌙 1
# 😲 1
# 🎶 4
# 📙 1
# 🖋 1
# ⚡ 9
# 🎸 1
# 🌹 2
# 📷 1
# 😅 2
# 📣 12
# 📺 5
# 🤩 1
# 🐊 1
# 🐔 11
# 🎆 2
# ☀ 1
# ❣ 4
# ♂ 1
# 🔽 1
# 🙈 1
# 😎 5
# 💡 2
# 💖 2
# 😷 2
# ⏳ 9
# 👀 9
# 💨 2
# 🙌 2
# 🎂 3
# ❤ 1
# ✍ 1
# ㊙ 1
# 🎬 3
# 🎁 3
# 💓 4
# 📻 2
# 🗓 1
# 💪 2
# 🍎 3
# 🎦 3
# ▪ 1
# 📸 8
# 👊 5
# ✅ 9
# 🤡 1
# 📖 2
# 💋 2
# 💥 14
# ▶ 4
# 🙏 1
# ㊗ 29
# 🌊 1
# 📰 1
# 😙 1
# ➡ 2
# 😮 1
# 📡 1
# 📢 2

# %%
def addmap (map):
    for c in map:
        if c in mapsum:
            mapsum[c]+=map[c]
            mapsum[sum]+=map[sum]
        else:
            mapsum[c]=map[sum]
addmap(map)    
for c in mapsum:
    print(c,mapsum[c])
# Out:
# 🤜 879
# 😲 879
# 🎥 879
# 📖 879
# 📽 879
# 😊 879
# 🔻 879
# 🤳 879
# 🙇 879
# 🤗 879
# 🚀 879
# 🎤 879
# 👏 879
# 📹 879
# 😂 879
# ❗ 879
# 👴 879
# 🎃 879
# 💕 879
# 👩 879
# 😇 879
# 📗 879
# 😄 879
# 🍻 879
# 💘 879
# <built-in function sum> 1758
# 😆 879
# 😀 879
# 🌋 879
# 🤔 879
# 🎓 879
# 💪 879
# 🎼 879
# ☺ 879
# ✊ 879
# 🕊 879
# ⁉ 879
# 🎦 879
# 🦌 879
# ♀ 879
# ⌛ 879
# 🍉 879
# 🗣 879
# 🚓 879
# 😭 879
# ⭕ 879
# 👍 879
# 🕺 879
# 🎵 879
# 🌃 879
# 🧐 879
# 🤩 879
# 👇 879
# 🤵 879
# 😁 879
# 👨 879
# ✖ 879
# 🏫 879
# 😢 879
# 🐾 879
# 👊 879
# 👉 879
# 🎙 879
# 📣 879
# 🌸 879
# 🎄 879
# ✨ 879
# ✌ 879
# 😵 879
# 🎅 879
# 🤣 879
# 👑 879
# 🔥 879
# ✔ 879
# ⤵ 879
# 💐 879
# 😏 879
# 📸 879
# 😉 879
# ❣ 879
# 🤫 879
# ⚠ 879
# 💋 879
# 😍 879
# ‼ 879
# 😱 879
# 👔 879
# 🤛 879
# 👓 879
# ❓ 879
# 💌 879
# 🃏 879
# 🌻 879
# 🎊 879
# 💞 879
# 🥊 879
# 🤶 879
# ⚫ 879
# 💡 879
# 🎶 879
# 📙 879
# 🖋 879
# ⚡ 879
# 🍓 879
# 🎸 879
# 🌹 879
# 📷 879
# 🐊 879
# 😅 879
# 💉 879
# 📺 879
# 🍊 879
# 🌟 879
# 🐔 879
# 😷 879
# 😘 879
# ❄ 879
# 🔽 879
# 🙈 879
# 😎 879
# 💖 879
# 🎆 879
# ⏳ 879
# 🌙 879
# 👀 879
# ♂ 879
# 🙌 879
# 🎂 879
# ❤ 879
# ㊙ 879
# 🎬 879
# 🎁 879
# 💓 879
# 📻 879
# 🗓 879
# ✍ 879
# 🍎 879
# 💊 879
# 💨 879
# ▪ 879
# 🏃 879
# 🖍 879
# 📢 879
# ✅ 879
# 🤡 879
# 🍀 879
# ☀ 879
# 💥 879
# ▶ 879
# 🙏 879
# ㊗ 879
# 🌊 879
# 📰 879
# 😙 879
# ➡ 879
# 😮 879
# 🎉 879
# 📡 879

# %%
'ShanChe45462516'
